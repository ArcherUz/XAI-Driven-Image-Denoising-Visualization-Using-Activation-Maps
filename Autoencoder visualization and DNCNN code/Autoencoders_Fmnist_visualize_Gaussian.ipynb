# %% [markdown]
# <h1 align="left">Using Autoencoders on MNIST Fashion Dataset</h1>
#
# Source Code = https://github.com/Rahulraj31/Autoencoder_MNIST-Fashion/blob/main/MNIST_Autoencoders.ipynb
#
# dataset = https://www.kaggle.com/zalando-research/fashionmnist

# %%
# check your gpu is available:
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

# for tensorflow instance:
import tensorflow as tf
device_name = tf.test.gpu_device_name()
# if device_name != '/device:GPU:0':
#   raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7610136824387514199
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14465892352
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15085526710090949493
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# Found GPU at: /device:GPU:0

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pylab as plt
from matplotlib import pyplot

from imgaug import augmenters
from random import randint

from tensorflow import keras
from tensorflow.keras import layers,losses
from tensorflow.keras.layers import Flatten,Dense, Input, Conv2D,MaxPool2D, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from numpy import argmax, array_equal

from tensorflow.keras.datasets import fashion_mnist, mnist

# %%
# read dataset
# https://keras.io/api/datasets/fashion_mnist/
#(train_x, train_y), (test_x, test_y) = mnist.load_data()
(train_x, train_y), (test_x, test_y) = fashion_mnist.load_data()
assert train_x.shape == (60000, 28, 28)
assert train_y.shape == (60000,)

assert test_x.shape == (10000, 28, 28)
assert test_y.shape == (10000,)

# train=pd.read_csv("/content/fashion-mnist_train.csv")
# train_x = train[list(train.columns[1:])].values
# train_y = train['label'].values
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# 26435584/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# # For Image Denoising

# %%
## create train and validation datasets
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, 
                                                  test_size=0.2,random_state=42)

# Normalize it 
train_x= train_x.astype(np.float32) / 255
val_x =val_x.astype(np.float32) /255
test_x =test_x.astype(np.float32) /255

# %%
#Reshaping data to specify channel for CNN
print(train_x.shape)
train_x = train_x.reshape(-1, 28, 28, 1)
print(train_x.shape)
val_x = val_x.reshape(-1, 28, 28, 1)
test_x = test_x.reshape(-1, 28, 28, 1)
# Out:
# (48000, 28, 28)
# (48000, 28, 28, 1)

# %% [markdown]
# **Noisy Images**
#
# We can intentionally introduce the noise in an image. I am using imaug package which can be used to augment the images with different variations. One such variation can be introduction of noise. Different types of noises can be added to the images. For example:
#
# Salt and Pepper Noise
#
# Gaussian Noise
#
# Periodic Noise
#
# Speckle Noise
#
# Lets introduce salt and pepper noise to our data which is also known as impulse noise. This noise introduces sharp and sudden disturbances in the image signal. It presents itself as sparsely occurring white and black pixels.

# %%
# Lets add sample noise - Salt and Pepper
noise = augmenters.AdditiveGaussianNoise(scale=0.1*255)
#noise = augmenters.AdditivePoissonNoise(lam=(15))
#noise = augmenters.AdditiveLaplaceNoise(scale=0.1*255)
#noise = augmenters.SaltAndPepper(0.1)

seq_object = augmenters.Sequential([noise])

train_x_n = seq_object.augment_images(train_x * 255) / 255
val_x_n = seq_object.augment_images(val_x * 255) / 255
test_x_n = seq_object.augment_images(test_x * 255) / 255

# %% [markdown]
# ### Before adding noise

# %%
f, ax = plt.subplots(1,5)
f.set_size_inches(80, 40)
for i in range(5,10):
    ax[i-5].imshow(train_x[i].reshape(28, 28), cmap='jet')
plt.show()

# %% [markdown]
# ### After adding noise

# %%
f, ax = plt.subplots(1,5)
f.set_size_inches(80, 40)
for i in range(5,10):
    ax[i-5].imshow(train_x_n[i].reshape(28, 28), cmap='jet')
plt.show()

# %% [markdown]
# ### Encoding Architecture:
#
# The encoding architure is composed of 3 Convolutional Layers and 3 Max Pooling Layers stacked one by one. Relu is used as the activation function in the convolution layers and padding is kept as "same". Role of max pooling layer is to downsample the image dimentions. This layer applies a max filter to non-overlapping subregions of the initial representation.
#
#
# ### Decoding Architecture:
#
# Similarly in decoding architecture, the convolution layers will be used having same dimentions (in reverse manner) as the encoding architecture. But instead of 3 maxpooling layers, we will be adding 3 upsampling layers. Again the activation function will be same (relu), and padding in convolution layers will be same as well. Role of upsampling layer is to upsample the dimentions of a input vector to a higher resolution / dimention. The max pooling operation is non-invertible, however an approximate inverse can be obtained by recording the locations of the maxima within each pooling region. Umsampling layers make use of this property to project the reconstructions from a low dimentional feature space.

# %%
# input layer 
input_layer = Input(shape=(28, 28, 1))

# Encoding Architecture
encoded_layer1 = Conv2D(64, (3, 3), activation='relu', padding='same')(input_layer)
encoded_layer1 = MaxPool2D( (2, 2), padding='same')(encoded_layer1)

encoded_layer2 = Conv2D(32, (3, 3), activation='relu', padding='same')(encoded_layer1)
encoded_layer2 = MaxPool2D( (2, 2), padding='same')(encoded_layer2)

encoded_layer3 = Conv2D(16, (3, 3), activation='relu', padding='same')(encoded_layer2)

latent_view    = MaxPool2D( (2, 2), padding='same')(encoded_layer3)

# decoding architecture
decoded_layer1 = Conv2D(16, (3, 3), activation='relu', padding='same')(latent_view)
decoded_layer1 = UpSampling2D((2, 2))(decoded_layer1)

decoded_layer2 = Conv2D(32, (3, 3), activation='relu', padding='same')(decoded_layer1)
decoded_layer2 = UpSampling2D((2, 2))(decoded_layer2)

decoded_layer3 = Conv2D(64, (3, 3), activation='relu')(decoded_layer2)
decoded_layer3 = UpSampling2D((2, 2))(decoded_layer3)


output_layer   = Conv2D(1, (3, 3), padding='same')(decoded_layer3)

#dimension of output layer == input layer coz we need denoised image thats why there is no dense layer only Conv layer

# %%
# compile the model
model = Model(input_layer, output_layer)
model.compile(optimizer=Adam(learning_rate=0.0005), loss='mse', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 16)          4624
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 16)          2320
#
#  up_sampling2d (UpSampling2D  (None, 8, 8, 16)         0
#  )
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 32)          4640
#
#  up_sampling2d_1 (UpSampling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 64)        18496
#
#  up_sampling2d_2 (UpSampling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 1)         577
#
# =================================================================
# Total params: 49,761
# Trainable params: 49,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in model.layers:
  if 'conv' not in layer.name:
    continue
  filters, biases = layer.get_weights()
  print(layer.name, filters.shape)
# Out:
# conv2d (3, 3, 1, 64)
# conv2d_1 (3, 3, 64, 32)
# conv2d_2 (3, 3, 32, 16)
# conv2d_3 (3, 3, 16, 16)
# conv2d_4 (3, 3, 16, 32)
# conv2d_5 (3, 3, 32, 64)
# conv2d_6 (3, 3, 64, 1)

# %%
# Training

# early_stopping = EarlyStopping(monitor='val_loss', min_delta=0,
#                                patience=10, verbose=5, mode='auto')

# model_checkpoint = ModelCheckpoint("model.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='min', save_freq=10)

history = model.fit(train_x_n, train_x, epochs=100, batch_size=480, validation_data=(val_x_n, val_x), callbacks=[])
model.save("model.h5")
# Out:
# Epoch 1/100
# 100/100 [==============================] - 14s 35ms/step - loss: 0.0555 - accuracy: 0.4988 - val_loss: 0.0297 - val_accuracy: 0.5027
# Epoch 2/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0247 - accuracy: 0.5042 - val_loss: 0.0220 - val_accuracy: 0.5054
# Epoch 3/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0207 - accuracy: 0.5055 - val_loss: 0.0198 - val_accuracy: 0.5057
# Epoch 4/100
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0190 - accuracy: 0.5061 - val_loss: 0.0184 - val_accuracy: 0.5063
# Epoch 5/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0179 - accuracy: 0.5065 - val_loss: 0.0174 - val_accuracy: 0.5068
# Epoch 6/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0170 - accuracy: 0.5068 - val_loss: 0.0167 - val_accuracy: 0.5068
# Epoch 7/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0164 - accuracy: 0.5070 - val_loss: 0.0161 - val_accuracy: 0.5073
# Epoch 8/100
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0158 - accuracy: 0.5072 - val_loss: 0.0156 - val_accuracy: 0.5073
# Epoch 9/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0154 - accuracy: 0.5074 - val_loss: 0.0152 - val_accuracy: 0.5075
# Epoch 10/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0151 - accuracy: 0.5075 - val_loss: 0.0149 - val_accuracy: 0.5076
# Epoch 11/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0147 - accuracy: 0.5076 - val_loss: 0.0146 - val_accuracy: 0.5077
# Epoch 12/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0144 - accuracy: 0.5077 - val_loss: 0.0143 - val_accuracy: 0.5077
# Epoch 13/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0142 - accuracy: 0.5078 - val_loss: 0.0142 - val_accuracy: 0.5080
# Epoch 14/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0139 - accuracy: 0.5078 - val_loss: 0.0138 - val_accuracy: 0.5079
# Epoch 15/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0137 - accuracy: 0.5079 - val_loss: 0.0136 - val_accuracy: 0.5079
# Epoch 16/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0135 - accuracy: 0.5080 - val_loss: 0.0134 - val_accuracy: 0.5080
# Epoch 17/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0133 - accuracy: 0.5080 - val_loss: 0.0132 - val_accuracy: 0.5080
# Epoch 18/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0131 - accuracy: 0.5081 - val_loss: 0.0130 - val_accuracy: 0.5082
# Epoch 19/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0129 - accuracy: 0.5081 - val_loss: 0.0129 - val_accuracy: 0.5081
# Epoch 20/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0127 - accuracy: 0.5082 - val_loss: 0.0127 - val_accuracy: 0.5083
# Epoch 21/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0127 - accuracy: 0.5082 - val_loss: 0.0126 - val_accuracy: 0.5083
# Epoch 22/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0125 - accuracy: 0.5083 - val_loss: 0.0125 - val_accuracy: 0.5082
# Epoch 23/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0124 - accuracy: 0.5083 - val_loss: 0.0123 - val_accuracy: 0.5084
# Epoch 24/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0122 - accuracy: 0.5083 - val_loss: 0.0124 - val_accuracy: 0.5085
# Epoch 25/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0121 - accuracy: 0.5084 - val_loss: 0.0121 - val_accuracy: 0.5085
# Epoch 26/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0120 - accuracy: 0.5084 - val_loss: 0.0120 - val_accuracy: 0.5085
# Epoch 27/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0119 - accuracy: 0.5084 - val_loss: 0.0119 - val_accuracy: 0.5085
# Epoch 28/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0118 - accuracy: 0.5085 - val_loss: 0.0119 - val_accuracy: 0.5084
# Epoch 29/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0117 - accuracy: 0.5085 - val_loss: 0.0117 - val_accuracy: 0.5085
# Epoch 30/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0116 - accuracy: 0.5085 - val_loss: 0.0116 - val_accuracy: 0.5086
# Epoch 31/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0115 - accuracy: 0.5085 - val_loss: 0.0117 - val_accuracy: 0.5087
# Epoch 32/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0114 - accuracy: 0.5086 - val_loss: 0.0114 - val_accuracy: 0.5086
# Epoch 33/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0114 - accuracy: 0.5086 - val_loss: 0.0114 - val_accuracy: 0.5086
# Epoch 34/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0113 - accuracy: 0.5086 - val_loss: 0.0116 - val_accuracy: 0.5085
# Epoch 35/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0112 - accuracy: 0.5086 - val_loss: 0.0113 - val_accuracy: 0.5088
# Epoch 36/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0112 - accuracy: 0.5087 - val_loss: 0.0112 - val_accuracy: 0.5086
# Epoch 37/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0111 - accuracy: 0.5087 - val_loss: 0.0113 - val_accuracy: 0.5086
# Epoch 38/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0110 - accuracy: 0.5087 - val_loss: 0.0110 - val_accuracy: 0.5087
# Epoch 39/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0110 - accuracy: 0.5087 - val_loss: 0.0110 - val_accuracy: 0.5088
# Epoch 40/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0109 - accuracy: 0.5087 - val_loss: 0.0109 - val_accuracy: 0.5087
# Epoch 41/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0108 - accuracy: 0.5087 - val_loss: 0.0111 - val_accuracy: 0.5086
# Epoch 42/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0108 - accuracy: 0.5087 - val_loss: 0.0108 - val_accuracy: 0.5088
# Epoch 43/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0107 - accuracy: 0.5088 - val_loss: 0.0108 - val_accuracy: 0.5089
# Epoch 44/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0107 - accuracy: 0.5088 - val_loss: 0.0108 - val_accuracy: 0.5087
# Epoch 45/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0106 - accuracy: 0.5088 - val_loss: 0.0108 - val_accuracy: 0.5087
# Epoch 46/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0106 - accuracy: 0.5088 - val_loss: 0.0106 - val_accuracy: 0.5088
# Epoch 47/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0105 - accuracy: 0.5088 - val_loss: 0.0105 - val_accuracy: 0.5088
# Epoch 48/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0105 - accuracy: 0.5088 - val_loss: 0.0106 - val_accuracy: 0.5090
# Epoch 49/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0104 - accuracy: 0.5088 - val_loss: 0.0105 - val_accuracy: 0.5089
# Epoch 50/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0104 - accuracy: 0.5088 - val_loss: 0.0105 - val_accuracy: 0.5088
# Epoch 51/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0103 - accuracy: 0.5088 - val_loss: 0.0104 - val_accuracy: 0.5088
# Epoch 52/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0103 - accuracy: 0.5089 - val_loss: 0.0103 - val_accuracy: 0.5089
# Epoch 53/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0103 - accuracy: 0.5089 - val_loss: 0.0103 - val_accuracy: 0.5089
# Epoch 54/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0103 - accuracy: 0.5089 - val_loss: 0.0105 - val_accuracy: 0.5088
# Epoch 55/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0102 - accuracy: 0.5089 - val_loss: 0.0102 - val_accuracy: 0.5089
# Epoch 56/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0101 - accuracy: 0.5089 - val_loss: 0.0102 - val_accuracy: 0.5089
# Epoch 57/100
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0101 - accuracy: 0.5089 - val_loss: 0.0102 - val_accuracy: 0.5089
# Epoch 58/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0101 - accuracy: 0.5089 - val_loss: 0.0101 - val_accuracy: 0.5090
# Epoch 59/100
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0101 - accuracy: 0.5089 - val_loss: 0.0101 - val_accuracy: 0.5089
# Epoch 60/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0100 - accuracy: 0.5089 - val_loss: 0.0101 - val_accuracy: 0.5090
# Epoch 61/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0100 - accuracy: 0.5089 - val_loss: 0.0100 - val_accuracy: 0.5090
# Epoch 62/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0100 - accuracy: 0.5089 - val_loss: 0.0101 - val_accuracy: 0.5089
# Epoch 63/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0099 - accuracy: 0.5089 - val_loss: 0.0100 - val_accuracy: 0.5090
# Epoch 64/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0099 - accuracy: 0.5089 - val_loss: 0.0099 - val_accuracy: 0.5090
# Epoch 65/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0098 - accuracy: 0.5090 - val_loss: 0.0102 - val_accuracy: 0.5089
# Epoch 66/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0098 - accuracy: 0.5090 - val_loss: 0.0099 - val_accuracy: 0.5090
# Epoch 67/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0098 - accuracy: 0.5090 - val_loss: 0.0098 - val_accuracy: 0.5090
# Epoch 68/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0098 - accuracy: 0.5090 - val_loss: 0.0098 - val_accuracy: 0.5090
# Epoch 69/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0098 - accuracy: 0.5090 - val_loss: 0.0098 - val_accuracy: 0.5090
# Epoch 70/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0097 - accuracy: 0.5090 - val_loss: 0.0098 - val_accuracy: 0.5090
# Epoch 71/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0098 - accuracy: 0.5090 - val_loss: 0.0097 - val_accuracy: 0.5090
# Epoch 72/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0097 - accuracy: 0.5090 - val_loss: 0.0097 - val_accuracy: 0.5090
# Epoch 73/100
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0096 - accuracy: 0.5090 - val_loss: 0.0100 - val_accuracy: 0.5089
# Epoch 74/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0096 - accuracy: 0.5090 - val_loss: 0.0097 - val_accuracy: 0.5091
# Epoch 75/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0096 - accuracy: 0.5090 - val_loss: 0.0097 - val_accuracy: 0.5090
# Epoch 76/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0096 - accuracy: 0.5090 - val_loss: 0.0097 - val_accuracy: 0.5090
# Epoch 77/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0096 - accuracy: 0.5090 - val_loss: 0.0096 - val_accuracy: 0.5091
# Epoch 78/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0095 - accuracy: 0.5090 - val_loss: 0.0098 - val_accuracy: 0.5092
# Epoch 79/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0095 - accuracy: 0.5090 - val_loss: 0.0097 - val_accuracy: 0.5092
# Epoch 80/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0095 - accuracy: 0.5090 - val_loss: 0.0096 - val_accuracy: 0.5090
# Epoch 81/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0094 - accuracy: 0.5090 - val_loss: 0.0095 - val_accuracy: 0.5091
# Epoch 82/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0095 - accuracy: 0.5090 - val_loss: 0.0095 - val_accuracy: 0.5091
# Epoch 83/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0094 - accuracy: 0.5091 - val_loss: 0.0095 - val_accuracy: 0.5091
# Epoch 84/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0094 - accuracy: 0.5091 - val_loss: 0.0095 - val_accuracy: 0.5092
# Epoch 85/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0094 - accuracy: 0.5091 - val_loss: 0.0095 - val_accuracy: 0.5090
# Epoch 86/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0094 - accuracy: 0.5091 - val_loss: 0.0095 - val_accuracy: 0.5090
# Epoch 87/100
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0094 - accuracy: 0.5091 - val_loss: 0.0094 - val_accuracy: 0.5091
# Epoch 88/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0093 - accuracy: 0.5091 - val_loss: 0.0094 - val_accuracy: 0.5091
# Epoch 89/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0093 - accuracy: 0.5091 - val_loss: 0.0094 - val_accuracy: 0.5091
# Epoch 90/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0094 - accuracy: 0.5091 - val_loss: 0.0094 - val_accuracy: 0.5091
# Epoch 91/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0093 - accuracy: 0.5091 - val_loss: 0.0094 - val_accuracy: 0.5091
# Epoch 92/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0093 - accuracy: 0.5091 - val_loss: 0.0093 - val_accuracy: 0.5091
# Epoch 93/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0093 - accuracy: 0.5091 - val_loss: 0.0093 - val_accuracy: 0.5091
# Epoch 94/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0092 - accuracy: 0.5091 - val_loss: 0.0093 - val_accuracy: 0.5092
# Epoch 95/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0092 - accuracy: 0.5091 - val_loss: 0.0093 - val_accuracy: 0.5091
# Epoch 96/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0092 - accuracy: 0.5091 - val_loss: 0.0093 - val_accuracy: 0.5091
# Epoch 97/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0092 - accuracy: 0.5091 - val_loss: 0.0095 - val_accuracy: 0.5092
# Epoch 98/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0092 - accuracy: 0.5091 - val_loss: 0.0094 - val_accuracy: 0.5090
# Epoch 99/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0092 - accuracy: 0.5091 - val_loss: 0.0092 - val_accuracy: 0.5092
# Epoch 100/100
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0091 - accuracy: 0.5091 - val_loss: 0.0092 - val_accuracy: 0.5091

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(6,8))
ax1.plot(epochs, acc, 'co', label='Training Accuracy')
ax1.plot(epochs, val_acc, 'r', label='Validation Accuracy')
ax1.set_title('Training and Validation Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.xaxis.grid(True)
ax1.yaxis.grid(True)
ax1.legend()

ax2.plot(epochs, loss, 'yo', label='Training Loss')
ax2.plot(epochs, val_loss, 'm', label='Validation Loss')
ax2.set_title('Training and Validation Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.xaxis.grid(True)
ax2.yaxis.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()

# %%
model = keras.models.load_model("model.h5")

# %% [markdown]
# Increase epochs and tune it for better accuracy Lets obtain the predictions of the model

# %%
f, ax = plt.subplots(1,5)
f.set_size_inches(80, 40)
for i in range(5,10):
    ax[i-5].imshow(test_x_n[i].reshape(28, 28), cmap='gray')
plt.show()

# %%
preds = model.predict(test_x_n[:10])
f, ax = plt.subplots(1,5)
f.set_size_inches(80, 40)
for i in range(5,10):
    ax[i-5].imshow(preds[i].reshape(28, 28), cmap='gray')
plt.show()

# %%
noised_image = test_x_n[7:8]

fig, ax = plt.subplots(1,1)
fig.set_size_inches(10, 10)
fig.suptitle("Input", fontsize=15)
ax.set_xticks([])
ax.set_yticks([])
ax.imshow(noised_image.reshape(28, 28), cmap='jet')
plt.show()
print()

outputs=[]
for layer in model.layers:
  if 'conv' in layer.name:
    outputs.append(layer.output)

model = Model(inputs=model.inputs, outputs=outputs)
feature_maps = model.predict(noised_image)

fig_dim = [[8,8],[4,8],[4,4],[4,4],[4,8],[8,8],[1,1]]
layers=[]
for layer in model.layers:
  if 'conv' not in layer.name:
    continue
  layers.append(layer)

for dim, fmap, layer in zip(fig_dim, feature_maps, layers):
  filters, biases = layer.get_weights()
  row = dim[0]
  col = dim[1]
  fig = plt.figure(figsize=(10,10))
  fig.suptitle(str(layer.name)+str(filters.shape) , fontsize=15)
  ix = 1
  for _ in range(row):
    for _ in range(col):
      ax = fig.add_subplot(row, col, ix)
      ax.set_xticks([])
      ax.set_yticks([])
      ax.imshow(fmap[0, :, :, ix-1], cmap='jet', alpha=1)
      ix += 1
  plt.show()
  print()
